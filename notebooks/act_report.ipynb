# %% [markdown]
# # Data Visualization and Analysis WeRateDogs

# %% [markdown]
# ## Relation between Retweets and Favorites of WeRatesDogs tweets

# %% [markdown]
# ![index1.png](attachment:index1.png)

# %% [markdown]
# **Interpretation:** based on the graph above, one can understand that the higher the count of retweets, the higher the count of favorites.

# %% [markdown]
# ## Rating Numerator evolution over Time

# %% [markdown]
# ![index2.png](attachment:index2.png)

# %% [markdown]
# **Interpretation:** the older WeRateDogs has existed, the less ratings around and below 10 have been given to dogs tweets on their account.

# %% [markdown]
# ## Evolution of Retweets and Favorites over time

# %% [markdown]
# ![index3.png](attachment:index3.png)

# %% [markdown]
# **Interpretation:** with the assumption that the count of retweets and count of favorites per tweet are reliable proxy for the popularity of a Twitter account, the graph above illustrate the popularity evolution of the WeRateDogs Twitter account over time

# %% [markdown]
# ## Top 10 rated Dog breeds

# %% [markdown]
# ![index4.png](attachment:index4.png)

# %% [markdown]
# **Interpretation:** the graph above represents the top 10 top rating dog breeds by mean of numerator rating, all of them being above 11/10 in average.
